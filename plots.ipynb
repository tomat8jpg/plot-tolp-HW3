# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(7, 10), sharex=True, sharey=True)

y = [3, 10, 13.5, 13.5]
x = [0, 50, 100, 150]
e = [3, 3.5, 3.5, 2]
a = [4, 2, 3, 3]
b = [4.5, 10, 10.4, 13]
c = [2.5, 3, 3, 2.5]
d = [4, 7, 6.5, 9]
labels = ['0', '50', '100', '200']

ax3.plot(x, y, linestyle="-", marker="o", color="k")
ax3.plot(x, e, linestyle="-", marker="^", color="k")
ax3.plot([47, 97, 147], [11, 14.5, 14.5], '.', color='k')
ax3.plot([53, 103, 153], [11, 14.5, 14.5], '^', markersize=4, color='k')
ax3.set_xlabel('Dose of ATP (mM)', fontsize=14)
ax3.set_yticks([0, 2, 4, 6, 8, 10, 12, 14, 16])
ax3.set_xticks([0, 50, 100, 150])
ax3.set_xticklabels(labels)
ax3.set_ylim(0, 18)

ax2.plot(x, a, linestyle="-", marker="^", color="k")
ax2.plot(x, b, linestyle="-", marker="o", color="k")
ax2.plot([47, 97, 147], [11.5, 12, 14], '.', color='k')
ax2.plot([53, 103, 153], [11.5, 12, 14], '^', markersize=4, color='k')
ax2.set_ylabel('Withdrawal latency (s)', fontsize=14)


ax1.plot(x, c, linestyle="-", marker="^", color="k")
ax1.plot(x, d, linestyle="-", marker="o", color="k")
ax1.plot([50, 100, 150], [8.5, 8.4, 10.5],  '.', color='k')
ax1.set_title

plt.text(0, 16, "LV.administration", fontsize=14)
plt.text(0, 34, "Oral administration", fontsize=14)
plt.text(0, 52, "Local administration", fontsize=14)

plt.subplots_adjust(hspace=0)
